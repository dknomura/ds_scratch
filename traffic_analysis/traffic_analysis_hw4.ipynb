# %%
import pandas as pd

stations_df = pd.DataFrame(
    [
        [768328, 'GAREY', 45.623, 44.1],
        [717241, 'FAIRPLEX', 43.76, 42.3],
        [717243, 'DUDLEY', 44.13, 42.6],
        [716187, 'CLEVELAND', 44.68, 43.2],
        [717247, 'WHITE', 45.16, 43.7],
        [717251, 'ORANGE GROVE', 46.01, 44.5],
        [717254, 'TOWNE', 46.56, 45.1],
    ],
    columns=['ID', 'Description', 'PM', 'Abs PM']
)
stations_df
# Out:
#        ID   Description      PM  Abs PM
# 0  768328         GAREY  45.623    44.1
# 1  717241      FAIRPLEX  43.760    42.3
# 2  717243        DUDLEY  44.130    42.6
# 3  716187     CLEVELAND  44.680    43.2
# 4  717247         WHITE  45.160    43.7
# 5  717251  ORANGE GROVE  46.010    44.5
# 6  717254         TOWNE  46.560    45.1

# %%
MISSING_DATA_FILE = r"C:\Users\dknom\Documents\school\CE5620_traffic_analysis\hw\CE5620-Homework4\S5_768328_flow_occ_missing_data02112026.xlsx"

missing_data_df = pd.read_excel(MISSING_DATA_FILE)
missing_data_df
# Out:
#              Sample Time  768328 Lane 1 Flow  768328 Lane 2 Flow  \
# 0    2026-02-11 00:00:08                 3.0                 6.0
# 1    2026-02-11 00:00:38                 4.0                 4.0
# 2    2026-02-11 00:01:08                 3.0                 4.0
# 3    2026-02-11 00:01:38                 6.0                 4.0
# 4    2026-02-11 00:02:08                 2.0                 4.0
# ...                  ...                 ...                 ...
# 2602 2026-02-11 23:57:38                 4.0                 3.0
# 2603 2026-02-11 23:58:08                 2.0                 1.0
# 2604 2026-02-11 23:58:38                 4.0                 3.0
# 2605 2026-02-11 23:59:08                 2.0                 8.0
# 2606 2026-02-11 23:59:38                 4.0                 7.0
#
#       768328 Lane 3 Flow  768328 Lane 4 Flow  768328 Lane 1 Occupancy (%)  \
# 0                    1.0                 1.0                         1.78
# ...

# %%
import glob

same_day_files = glob.glob(r'C:\Users\dknom\Documents\school\CE5620_traffic_analysis\hw\CE5620-Homework4\*02112026.xlsx')
