# %%
import pandas as pd
import numpy as np

AVE_SPEED = 60
stdev = 5
NUM_TRIALS= 30
mean_speeds = {"num_vehicles": np.array([]), "tms": np.array([]), "sms": np.array([])}

for idx, x in enumerate(range(NUM_TRIALS)):
    num_vehicles = idx + 1
    speeds = np.random.normal(AVE_SPEED, stdev, num_vehicles)
    mean_speeds["num_vehicles"] = np.append(mean_speeds["num_vehicles"], num_vehicles)
    mean_speeds["tms"] = np.append(mean_speeds["tms"], np.mean(speeds))
    mean_speeds["sms"] = np.append(
        mean_speeds["sms"], num_vehicles / (np.sum(1 / speeds))
    )

mean_speeds_df = pd.DataFrame(mean_speeds)

mean_speeds_df
# Out:
#     num_vehicles        tms        sms
# 0            1.0  52.348895  52.348895
# 1            2.0  57.640667  57.520467
# 2            3.0  60.899398  60.371378
# 3            4.0  58.910805  58.866457
# 4            5.0  58.428950  57.816590
# 5            6.0  60.298731  60.085519
# 6            7.0  64.753952  64.610948
# 7            8.0  63.268435  62.864696
# 8            9.0  61.784416  61.583970
# 9           10.0  60.067807  59.697101
# 10          11.0  62.043890  61.525497
# 11          12.0  60.997173  60.579202
# 12          13.0  63.406306  62.978677
# 13          14.0  62.833389  62.518056
# 14          15.0  59.568226  59.378502
# 15          16.0  61.426298  61.225431
# 16          17.0  60.084189  59.630934
# 17          18.0  60.506174  60.024047
# 18          19.0  58.934910  58.637201
# 19          20.0  59.213394  58.895796
# 20          21.0  59.219689  58.705273
# 21          22.0  60.035497  59.640770
# 22          23.0  58.920990  58.536077
# 23          24.0  59.269031  58.838154
# 24          25.0  58.099824  57.811855
# 25          26.0  59.874496  59.496542
# 26          27.0  60.363011  59.507095
# 27          28.0  60.281755  59.930611
# 28          29.0  59.503926  59.345694
# 29          30.0  59.929427  59.542556

# %%
import plotly.graph_objects as go
import plotly.io as pio

pio.renderers = 'browser'
fig = go.Figure(
    layout=go.Layout(
        title="Mean Speeds vs Number of Vehicles",
        xaxis_title="Number of Vehicles",
        yaxis_title="Mean Speed (mi/hr)",
    )
)

fig.add_trace(
    go.Scatter(
        x=mean_speeds["num_vehicles"],
        y=mean_speeds["tms"],
        name="TMS",
    )
)
fig.add_trace(
    go.Scatter(
        x=mean_speeds["num_vehicles"],
        y=mean_speeds["sms"],
        name="SMS",
    )
)

fig.show()
