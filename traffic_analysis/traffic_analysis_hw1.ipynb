# %%
import pandas as pd
import numpy as np

AVE_SPEED = 60
stdev = 5
NUM_TRIALS= 30
mean_speeds = {"num_vehicles": np.array([]), "tms": np.array([]), "sms": np.array([])}

for idx, x in enumerate(range(NUM_TRIALS)):
    num_vehicles = idx + 1
    speeds = np.random.normal(AVE_SPEED, stdev, num_vehicles)
    mean_speeds["num_vehicles"] = np.append(mean_speeds["num_vehicles"], num_vehicles)
    mean_speeds["tms"] = np.append(mean_speeds["tms"], np.mean(speeds))
    mean_speeds["sms"] = np.append(
        mean_speeds["sms"], num_vehicles / (np.sum(1 / speeds))
    )

mean_speeds_df = pd.DataFrame(mean_speeds)

mean_speeds_df.truncate()
# Out:
#     num_vehicles        tms        sms
# 0            1.0  47.471495  47.471495
# 1            2.0  58.739863  58.720457
# 2            3.0  63.834358  63.703439
# 3            4.0  64.218803  63.998814
# 4            5.0  54.915543  54.840873
# 5            6.0  61.749565  60.808525
# 6            7.0  57.808081  57.318476
# 7            8.0  61.630968  61.415804
# 8            9.0  60.869029  60.521014
# 9           10.0  59.812105  59.558937
# 10          11.0  57.618090  56.801962
# 11          12.0  59.772999  59.590416
# 12          13.0  59.911660  59.701090
# 13          14.0  60.266500  60.167332
# 14          15.0  60.959176  60.520795
# 15          16.0  61.465106  61.099856
# 16          17.0  58.787110  58.277677
# 17          18.0  60.080122  59.855489
# 18          19.0  58.068753  57.650933
# 19          20.0  58.775744  58.308277
# 20          21.0  59.611103  58.966504
# 21          22.0  60.345532  59.685357
# 22          23.0  59.904855  59.714751
# 23          24.0  60.846640  60.521706
# 24          25.0  60.622479  60.261462
# 25          26.0  59.157711  58.724408
# 26          27.0  60.060170  59.755089
# 27          28.0  59.429470  59.096680
# 28          29.0  60.139662  59.800219
# 29          30.0  59.802909  59.280495

# %%
import plotly.graph_objects as go

fig = go.Figure(
    layout=go.Layout(
        title="Mean Speeds vs Number of Vehicles",
        xaxis_title="Number of Vehicles",
        yaxis_title="Mean Speed (mi/hr)",
    )
)

fig.add_trace(
    go.Scatter(
        x=mean_speeds["num_vehicles"],
        y=mean_speeds["tms"],
        name="TMS",
    )
)
fig.add_trace(
    go.Scatter(
        x=mean_speeds["num_vehicles"],
        y=mean_speeds["sms"],
        name="SMS",
    )
)

fig.show()
