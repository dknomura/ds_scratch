# %%
import pandas as pd
import numpy as np

AVE_SPEED = 60
stdev = 5
NUM_TRIALS= 30
mean_speeds = {"num_vehicles": np.array([]), "tms": np.array([]), "sms": np.array([])}

for idx, x in enumerate(range(NUM_TRIALS)):
    num_vehicles = idx + 1
    speeds = np.random.normal(AVE_SPEED, stdev, num_vehicles)
    mean_speeds["num_vehicles"] = np.append(mean_speeds["num_vehicles"], num_vehicles)
    mean_speeds["tms"] = np.append(mean_speeds["tms"], np.mean(speeds))
    mean_speeds["sms"] = np.append(
        mean_speeds["sms"], num_vehicles / (np.sum(1 / speeds))
    )

mean_speeds_df = pd.DataFrame(mean_speeds)

mean_speeds_df
# Out:
#     num_vehicles        tms        sms
# 0            1.0  65.992023  65.992023
# 1            2.0  59.329493  59.277181
# 2            3.0  56.016606  55.737761
# 3            4.0  60.703372  60.366751
# 4            5.0  60.428645  60.382830
# 5            6.0  58.174844  57.670858
# 6            7.0  59.331770  58.807518
# 7            8.0  58.766606  58.630106
# 8            9.0  62.152397  61.861845
# 9           10.0  61.060385  60.738399
# 10          11.0  58.109138  57.474813
# 11          12.0  59.583029  59.215602
# 12          13.0  60.009235  59.452110
# 13          14.0  59.045313  58.733762
# 14          15.0  60.708487  60.356056
# 15          16.0  60.506972  60.295112
# 16          17.0  61.510877  61.290339
# 17          18.0  62.845735  62.672193
# 18          19.0  59.756847  59.515138
# 19          20.0  58.166602  57.810645
# 20          21.0  60.735040  60.347972
# 21          22.0  60.519339  60.137481
# 22          23.0  59.634621  59.143063
# ...

# %%
import plotly.graph_objects as go
import plotly.io as pio 

pio.renderers = "notebook_connected"

fig = go.Figure(
    layout=go.Layout(
        title="Mean Speeds vs Number of Vehicles",
        xaxis_title="Number of Vehicles",
        yaxis_title="Mean Speed (mi/hr)",
    )
)

fig.add_trace(
    go.Scatter(
        x=mean_speeds["num_vehicles"],
        y=mean_speeds["tms"],
        name="TMS",
    )
)
fig.add_trace(
    go.Scatter(
        x=mean_speeds["num_vehicles"],
        y=mean_speeds["sms"],
        name="SMS",
    )
)

fig.show()
