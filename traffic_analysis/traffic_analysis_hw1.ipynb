# %%
import pandas as pd
import numpy as np

AVE_SPEED = 60
stdev = 5
NUM_TRIALS= 30
mean_speeds = {"num_vehicles": np.array([]), "tms": np.array([]), "sms": np.array([])}

for idx, x in enumerate(range(NUM_TRIALS)):
    num_vehicles = idx + 1
    speeds = np.random.normal(AVE_SPEED, stdev, num_vehicles)
    mean_speeds["num_vehicles"] = np.append(mean_speeds["num_vehicles"], num_vehicles)
    mean_speeds["tms"] = np.append(mean_speeds["tms"], np.mean(speeds))
    mean_speeds["sms"] = np.append(
        mean_speeds["sms"], num_vehicles / (np.sum(1 / speeds))
    )

mean_speeds_df = pd.DataFrame(mean_speeds)

mean_speeds_df
# Out:
#     num_vehicles        tms        sms
# 0            1.0  60.149159  60.149159
# 1            2.0  55.647732  55.529429
# 2            3.0  57.578028  56.844394
# 3            4.0  58.274812  58.022621
# 4            5.0  57.418151  56.817016
# 5            6.0  59.387164  58.979034
# 6            7.0  61.099134  60.493304
# 7            8.0  59.423581  58.739027
# 8            9.0  58.730576  58.406879
# 9           10.0  57.024697  56.692358
# 10          11.0  59.506597  58.793653
# 11          12.0  59.713773  59.437900
# 12          13.0  59.908139  59.620068
# 13          14.0  59.324040  58.644473
# 14          15.0  61.983261  61.676098
# 15          16.0  61.863981  61.397141
# 16          17.0  60.522399  60.068277
# 17          18.0  59.079147  58.688995
# 18          19.0  60.608563  59.968823
# 19          20.0  58.923360  58.401596
# 20          21.0  59.730758  59.440139
# 21          22.0  60.331202  60.006183
# 22          23.0  60.199273  59.693067
# 23          24.0  58.168602  57.977036
# 24          25.0  60.565839  60.166032
# 25          26.0  60.756727  60.422768
# 26          27.0  60.921293  60.583948
# 27          28.0  60.003347  59.749175
# 28          29.0  61.020064  60.600458
# 29          30.0  59.649596  59.158261

# %%
import plotly.graph_objects as go

fig = go.Figure(
    layout=go.Layout(
        title="Mean Speeds vs Number of Vehicles",
        xaxis_title="Number of Vehicles",
        yaxis_title="Mean Speed (mi/hr)",
    )
)

fig.add_trace(
    go.Scatter(
        x=mean_speeds["num_vehicles"],
        y=mean_speeds["tms"],
        name="TMS",
    )
)
fig.add_trace(
    go.Scatter(
        x=mean_speeds["num_vehicles"],
        y=mean_speeds["sms"],
        name="SMS",
    )
)

fig.show(renderer="pdf+vscode")
