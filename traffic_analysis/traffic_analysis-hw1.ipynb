# %%
import pandas as pd
import numpy as np

AVE_SPEED = 60
stdev = 5
NUM_TRIALS= 30
mean_speeds = {"num_vehicles": np.array([]), "tms": np.array([]), "sms": np.array([])}

for idx, x in enumerate(range(NUM_TRIALS)):
    num_vehicles = idx + 1
    speeds = np.random.normal(AVE_SPEED, stdev, num_vehicles)
    mean_speeds["num_vehicles"] = np.append(mean_speeds["num_vehicles"], num_vehicles)
    mean_speeds["tms"] = np.append(mean_speeds["tms"], np.mean(speeds))
    mean_speeds["sms"] = np.append(
        mean_speeds["sms"], num_vehicles / (np.sum(1 / speeds))
    )

mean_speeds_df = pd.DataFrame(mean_speeds)

mean_speeds_df
# Out:
#     num_vehicles        tms        sms
# 0            1.0  62.801325  62.801325
# 1            2.0  59.004860  58.845983
# 2            3.0  58.073179  57.335700
# 3            4.0  58.044222  57.708205
# 4            5.0  64.127381  63.905278
# 5            6.0  58.981992  58.844356
# 6            7.0  63.343606  63.110150
# 7            8.0  60.133910  59.916808
# 8            9.0  55.945759  55.045320
# 9           10.0  61.943948  61.352822
# 10          11.0  59.038644  58.520680
# 11          12.0  59.829683  58.883476
# 12          13.0  59.843065  59.456197
# 13          14.0  58.459419  57.935405
# 14          15.0  60.233055  59.981014
# 15          16.0  59.685385  59.212141
# 16          17.0  59.764327  59.613955
# 17          18.0  56.752726  56.485368
# 18          19.0  60.778251  60.407267
# 19          20.0  59.114591  58.781283
# 20          21.0  58.739243  58.255381
# 21          22.0  59.841296  59.272056
# 22          23.0  58.234052  57.802192
# 23          24.0  58.836318  58.366312
# 24          25.0  61.127982  60.764734
# 25          26.0  60.393328  60.104580
# 26          27.0  59.969132  59.407525
# 27          28.0  59.663092  59.394876
# 28          29.0  60.065713  59.614359
# 29          30.0  57.097311  56.453829

# %%
import plotly.graph_objects as go
import plotly.io as pio 

pio.renderers = "browser"

fig = go.Figure(
    layout=go.Layout(
        title="Mean Speeds vs Number of Vehicles",
        xaxis_title="Number of Vehicles",
        yaxis_title="Mean Speed (mi/hr)",
    )
)

fig.add_trace(
    go.Scatter(
        x=mean_speeds["num_vehicles"],
        y=mean_speeds["tms"],
        name="TMS",
    )
)
fig.add_trace(
    go.Scatter(
        x=mean_speeds["num_vehicles"],
        y=mean_speeds["sms"],
        name="SMS",
    )
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 29
#      14 fig.add_trace(
#      15     go.Scatter(
#      16         x=mean_speeds["num_vehicles"],
#    (...)     19     )
#      20 )
#      21 fig.add_trace(
#      22     go.Scatter(
#      23         x=mean_speeds["num_vehicles"],
#    (...)     26     )
#      27 )
# ---> 29 fig.show(renderer="pdf")
#
# File c:\Users\dknom\Documents\Code\ds_scratch\.pixi\envs\default\Lib\site-packages\plotly\basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)   3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File c:\Users\dknom\Documents\Code\ds_scratch\.pixi\envs\default\Lib\site-packages\plotly\io\_renderers.py:407, in show(fig, renderer, validate, **kwargs)
#     404 fig_dict = validate_coerce_fig_to_dict(fig, validate)
#     406 # Mimetype renderers
# --> 407 bundle = renderers._build_mime_bundle(fig_dict, renderers_string=renderer, **kwargs)
#     408 if bundle:
#     409     if not ipython_display:
#
# File c:\Users\dknom\Documents\Code\ds_scratch\.pixi\envs\default\Lib\site-packages\plotly\io\_renderers.py:315, in RenderersConfig._build_mime_bundle(self, fig_dict, renderers_string, **kwargs)
#     312             if hasattr(renderer, k):
#     313                 setattr(renderer, k, v)
# --> 315         bundle.update(renderer.to_mimebundle(fig_dict))
#     317 return bundle
#
# File c:\Users\dknom\Documents\Code\ds_scratch\.pixi\envs\default\Lib\site-packages\plotly\io\_base_renderers.py:123, in ImageRenderer.to_mimebundle(self, fig_dict)
#     122 def to_mimebundle(self, fig_dict):
# --> 123     image_bytes = to_image(
#     124         fig_dict,
#     125         format=self.format,
#     126         width=self.width,
#     127         height=self.height,
#     128         scale=self.scale,
#     129         validate=False,
#     130         engine=self.engine,
#     131     )
#     133     if self.b64_encode:
#     134         image_str = base64.b64encode(image_bytes).decode("utf8")
#
# File c:\Users\dknom\Documents\Code\ds_scratch\.pixi\envs\default\Lib\site-packages\plotly\io\_kaleido.py:345, in to_image(fig, format, width, height, scale, validate, engine)
#     343     # Raise informative error message if Kaleido is not installed
#     344     if not kaleido_available():
# --> 345         raise ValueError(
#     346             """
#     347 Image export using the "kaleido" engine requires the Kaleido package,
#     348 which can be installed using pip:
#     349
#     350     $ pip install --upgrade kaleido
#     351 """
#     352         )
#     354     # Convert figure to dict (and validate if requested)
#     355     fig_dict = validate_coerce_fig_to_dict(fig, validate)
#
# ValueError:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
