# %%
import pandas as pd
import numpy as np

AVE_SPEED = 60
stdev = 5
NUM_TRIALS= 30
mean_speeds = {"num_vehicles": np.array([]), "tms": np.array([]), "sms": np.array([])}

for idx, x in enumerate(range(NUM_TRIALS)):
    num_vehicles = idx + 1
    speeds = np.random.normal(AVE_SPEED, stdev, num_vehicles)
    mean_speeds["num_vehicles"] = np.append(mean_speeds["num_vehicles"], num_vehicles)
    mean_speeds["tms"] = np.append(mean_speeds["tms"], np.mean(speeds))
    mean_speeds["sms"] = np.append(
        mean_speeds["sms"], num_vehicles / (np.sum(1 / speeds))
    )

mean_speeds_df = pd.DataFrame(mean_speeds)

mean_speeds_df
# Out:
#     num_vehicles        tms        sms
# 0            1.0  52.128368  52.128368
# 1            2.0  54.400131  54.041128
# 2            3.0  59.054821  58.695135
# 3            4.0  59.860657  59.504618
# 4            5.0  62.069578  61.232721
# 5            6.0  59.597563  59.165763
# 6            7.0  63.433605  63.177548
# 7            8.0  59.670242  59.303504
# 8            9.0  61.722659  61.399562
# 9           10.0  60.629339  60.256708
# 10          11.0  59.348545  58.952042
# 11          12.0  58.956799  58.585640
# 12          13.0  60.888917  60.612444
# 13          14.0  59.263110  58.555561
# 14          15.0  60.075205  59.746714
# 15          16.0  60.186298  59.442235
# 16          17.0  58.981561  58.483510
# 17          18.0  60.983564  60.475632
# 18          19.0  59.548109  59.046081
# 19          20.0  62.654418  62.000800
# 20          21.0  59.638728  59.064907
# 21          22.0  60.108546  59.859232
# 22          23.0  60.850205  60.121583
# 23          24.0  60.109909  59.865995
# 24          25.0  61.591026  61.344541
# 25          26.0  58.468735  57.875376
# 26          27.0  59.861888  59.454558
# 27          28.0  59.876844  59.400211
# 28          29.0  59.901758  59.517929
# 29          30.0  60.032081  59.580262

# %%
import plotly.graph_objects as go
import plotly.io as pio 

pio.renderers = "browser"

fig = go.Figure(
    layout=go.Layout(
        title="Mean Speeds vs Number of Vehicles",
        xaxis_title="Number of Vehicles",
        yaxis_title="Mean Speed (mi/hr)",
    )
)

fig.add_trace(
    go.Scatter(
        x=mean_speeds["num_vehicles"],
        y=mean_speeds["tms"],
        name="TMS",
    )
)
fig.add_trace(
    go.Scatter(
        x=mean_speeds["num_vehicles"],
        y=mean_speeds["sms"],
        name="SMS",
    )
)

fig.show()
